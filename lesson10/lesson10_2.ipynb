# %% [markdown]
# https://www.perplexity.ai/search/e444a2ad-db91-4391-87be-a868c2f7c55f

# %%
import pandas as pd
df = pd.read_excel('個股日成交資訊.xlsx')
df.tail()
# Out:
#       證券代號  證券名稱        成交股數         成交金額    開盤價    最高價    最低價    收盤價   漲跌價差  \
# 1108  9944    新麗   1,463,020   22,024,560  15.60  15.60  14.60  14.65  -0.75
# 1109  9945   潤泰新   5,262,676  178,768,894  34.20  34.30  33.40  33.40  -0.65
# 1110  9946  三發地產     871,456   10,936,770  12.55  12.55  12.55  12.55  -1.35
# 1111  9955    佳龍     827,246   10,257,476  13.10  13.10  11.85  12.10  -0.50
# 1112  9958   世紀鋼  10,816,881  868,126,524  81.00  81.80  78.50  79.50  +0.90
#
#        成交筆數
# 1108    796
# 1109  3,169
# 1110     46
# 1111    412
# 1112  6,743
